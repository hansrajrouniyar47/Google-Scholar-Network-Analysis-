# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
import urllib3
from bs4 import BeautifulSoup
from collections import defaultdict
import requests

# %%
scholar = 'https://scholar.google.com/citations?user=x6fNSxcAAAAJ&hl=en'
nodes=100

# %%
def getGraph(seed, Nmax):
    urls = defaultdict(int)
    urls[seed]+=1
    newUrls = [seed]
    G = nx.DiGraph()
    
    def coAuthors(url):
        print(url)
        coUrls = []
        coNames = []
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        s = soup.body.findAll('a', {"tabindex": "-1"})
        egoName = soup.body.find('div', {"id": "gsc_prf_in"}).text 
        print(egoName)
        print("******")
        if s:
            for i in s:
                coNames.append(i.text) 
                #for network plot
                coUrls.append('http://scholar.google.nl'+ i['href'])
        for j in coUrls:
            urls[j] += 0
        for m in coNames:
            G.add_edge(egoName.split(',')[0], m.split(',')[0], weight = 1)
        return coUrls
    
    while newUrls:
        for k in urls.keys(): 
            # update url.values() first
            urls[k] += 1 
        addUrls = [] 
        # get new-added authors, may have duplications.
        for i in newUrls:
            
            #coAuthors(i)
            coUrls = coAuthors(i)
            if coUrls:
                for j in coUrls:
                    addUrls.append(j)
        for m in set(addUrls): 
            # get rid of the duplications
            urls[m] += 0
        newUrls = [k for k, v in urls.items() if v <= 1]
        # This is for updating the new coauthors and avoid the deadloop: a->b->a->......
        addUrls = []   
        print(len(urls.keys()))
        if len(urls.keys()) > Nmax:
            print('more than '+str(Nmax)+' people now, break')
            break
        print(newUrls)
    return G

# %%
def getName(seed, Nmax):
    #urls = defaultdict(int)
    G = nx.DiGraph()
    response = requests.get(seed)
    soup = BeautifulSoup(response.content, "html.parser")
    egoName = soup.body.find('div', {"id": "gsc_prf_in"}).text 
    print(egoName)
    return egoName

# %%
#get Name of the author
name = getName(scholar, nodes)
# Out:
# Justin Wolfers

# %%
#get coauthor List
g = getGraph(scholar, nodes)
# Out:
# https://scholar.google.com/citations?user=x6fNSxcAAAAJ&hl=en
# Justin Wolfers
# ******
# 21
# ['http://scholar.google.nl/citations?user=rN1w41IAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=x8wsLTcAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=xwATNO8AAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=QtVE6DwAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=NaSxLIQAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=DhflKwEAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=Ga0i--0AAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=9nDqa0EAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=ddq2_gkAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=S2t1x2oAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=GYmUFP8AAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=-x0qMAcAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=aXGTpLgAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=C0GF1AgAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=4_i_4TkAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=NIb-hRUAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?user=3aryrccAAAAJ&hl=en&oe=ASCII', 'http://scholar.google.nl/citations?hl=en&oe=ASCII&user=x6fNSxcAAAAJ&view_op=list_works', 'http://scholar.google.nl/citations?hl=en&oe=ASCII&user=x6fNSxcAAAAJ&view_op=list_works&sortby=pubdate', 'http://scholar.google.nl/citations?hl=en&oe=ASCII&user=x6fNSxcAAAAJ&view_op=list_works&sortby=title']
# http://scholar.google.nl/citations?user=rN1w41IAAAAJ&hl=en&oe=ASCII
# Betsey Stevenson
# ******
# http://scholar.google.nl/citations?user=x8wsLTcAAAAJ&hl=en&oe=ASCII
# Eric Zitzewitz
# ******
# http://scholar.google.nl/citations?user=xwATNO8AAAAJ&hl=en&oe=ASCII
# Erik Snowberg
# ******
# http://scholar.google.nl/citations?user=QtVE6DwAAAAJ&hl=en&oe=ASCII
# olivier blanchard
# ******
# http://scholar.google.nl/citations?user=NaSxLIQAAAAJ&hl=en&oe=ASCII
# Andrew Leigh
# ******
# http://scholar.google.nl/citations?user=DhflKwEAAAAJ&hl=en&oe=ASCII
# Daniel Sacks
# ******
# http://scholar.google.nl/citations?user=Ga0i--0AAAAJ&hl=en&oe=ASCII
# N. Gregory Mankiw
# ******
# http://scholar.google.nl/citations?user=9nDqa0EAAAAJ&hl=en&oe=ASCII
# Ricardo Reis
# ******
# http://scholar.google.nl/citations?user=ddq2_gkAAAAJ&hl=en&oe=ASCII
# Cass Sunstein
# ******
# http://scholar.google.nl/citations?user=S2t1x2oAAAAJ&hl=en&oe=ASCII
# Refet S. Gürkaynak
# ******
# http://scholar.google.nl/citations?user=GYmUFP8AAAAJ&hl=en&oe=ASCII
# Devin Pope
# ******
# http://scholar.google.nl/citations?user=-x0qMAcAAAAJ&hl=en&oe=ASCII
# Bo Cowgill
# ******
# http://scholar.google.nl/citations?user=aXGTpLgAAAAJ&hl=en&oe=ASCII
# David Rothschild
# ******
# http://scholar.google.nl/citations?user=C0GF1AgAAAAJ&hl=en&oe=ASCII
# Emile Servan-Schreiber
# ******
# http://scholar.google.nl/citations?user=4_i_4TkAAAAJ&hl=en&oe=ASCII
# David M Pennock
# ******
# http://scholar.google.nl/citations?user=NIb-hRUAAAAJ&hl=en&oe=ASCII
# Shane Jensen
# ******
# http://scholar.google.nl/citations?user=3aryrccAAAAJ&hl=en&oe=ASCII
# Abraham Wyner
# ******
# http://scholar.google.nl/citations?hl=en&oe=ASCII&user=x6fNSxcAAAAJ&view_op=list_works
# Justin Wolfers
# ******
# http://scholar.google.nl/citations?hl=en&oe=ASCII&user=x6fNSxcAAAAJ&view_op=list_works&sortby=pubdate
# Justin Wolfers
# ******
# http://scholar.google.nl/citations?hl=en&oe=ASCII&user=x6fNSxcAAAAJ&view_op=list_works&sortby=title
# Justin Wolfers
# ******
# 250
# more than 100 people now, break

# %%
def plot_(g):
    plt.figure(figsize = (30, 30))
    pos = nx.spring_layout(g) 
    nx.draw_networkx_labels(g, pos, font_color='k', font_size = 14)
    nx.draw(g, pos, node_size = 20, edge_color = 'grey', width = 0.4, arrows = True)
    #str1=name
    str2="'s Google Scholar Network"
    myTitle=str(name)+str2
    plt.title(myTitle, fontsize=40)
    #plt.xticks([])
    #plt.yticks([])
    plt.show()

# %%
plot_(g)

# %%
#create Important subnetwork
def page_Rank(G):
    print("Google Page Rank Algoritham\n")
    #rank=nx.pagerank(G).items()
    #rank=nx.betweenness_centrality(G).items()
    rank=nx.degree_centrality(G).items()
    #print(rank)
    for k,v in rank :
        print("Page Rank Centrality :",k,'\t',v)
        
    r = [x[1] for x in rank]
    rsum = sum(r)
    rlen = len(r)
    rfac = rsum/rlen
    Gt = G.copy()
    
    for k, v in rank:
        if v < rfac:
            Gt.remove_node(k)
    return Gt

# %%
Gt = page_Rank(g)
# Out:
# Google Page Rank Algoritham
#
# Page Rank Centrality : Justin Wolfers 	 0.16243654822335024
# Page Rank Centrality : Betsey Stevenson 	 0.025380710659898477
# Page Rank Centrality : Eric Zitzewitz 	 0.07106598984771573
# Page Rank Centrality : Erik Snowberg 	 0.12182741116751268
# Page Rank Centrality : olivier blanchard 	 0.12182741116751268
# Page Rank Centrality : Andrew Leigh 	 0.12182741116751268
# Page Rank Centrality : Daniel Sacks 	 0.02030456852791878
# Page Rank Centrality : N. Gregory Mankiw 	 0.12690355329949238
# Page Rank Centrality : Ricardo Reis 	 0.08629441624365482
# Page Rank Centrality : Cass Sunstein 	 0.09137055837563451
# Page Rank Centrality : Refet S. Gürkaynak 	 0.08629441624365482
# Page Rank Centrality : Devin Pope 	 0.02030456852791878
# Page Rank Centrality : Bo Cowgill 	 0.12690355329949238
# Page Rank Centrality : David Rothschild 	 0.09137055837563451
# Page Rank Centrality : Emile Servan-Schreiber 	 0.055837563451776644
# Page Rank Centrality : David M Pennock 	 0.13197969543147206
# Page Rank Centrality : Shane Jensen 	 0.050761421319796954
# Page Rank Centrality : Abraham Wyner 	 0.10659898477157359
# Page Rank Centrality : Sort by citations 	 0.09137055837563451
# Page Rank Centrality : Sort by year 	 0.09137055837563451
# Page Rank Centrality : Sort by title 	 0.09137055837563451
# Page Rank Centrality : Jonathan Reuter 	 0.005076142131979695
# Page Rank Centrality : Antti Petajisto 	 0.005076142131979695
# Page Rank Centrality : K. J. Martijn Cremers 	 0.005076142131979695
# Page Rank Centrality : Jonathan Zinman 	 0.005076142131979695
# Page Rank Centrality : Sylvain Chassang 	 0.005076142131979695
# Page Rank Centrality : Pietro Ortoleva 	 0.005076142131979695
# Page Rank Centrality : James Snyder 	 0.005076142131979695
# Page Rank Centrality : Marc Meredith 	 0.005076142131979695
# Page Rank Centrality : Gerard Padró i Miquel 	 0.005076142131979695
# Page Rank Centrality : Abhijit Banerjee 	 0.005076142131979695
# Page Rank Centrality : Leeat Yariv 	 0.005076142131979695
# Page Rank Centrality : Colin Camerer 	 0.005076142131979695
# Page Rank Centrality : Benjamin Gillen 	 0.005076142131979695
# Page Rank Centrality : Philippe Rigollet 	 0.005076142131979695
# Page Rank Centrality : Vianney Perchet 	 0.005076142131979695
# Page Rank Centrality : Mark Dean 	 0.005076142131979695
# Page Rank Centrality : Brendan Daley 	 0.005076142131979695
# Page Rank Centrality : Andrea Mattozzi 	 0.005076142131979695
# Page Rank Centrality : Ben Seymour 	 0.005076142131979695
# Page Rank Centrality : Neil Malhotra 	 0.01015228426395939
# Page Rank Centrality : Andrew Healy 	 0.005076142131979695
# Page Rank Centrality : Jordi Galí 	 0.005076142131979695
# Page Rank Centrality : Giovanni Dell'Ariccia 	 0.005076142131979695
# Page Rank Centrality : francesco giavazzi 	 0.005076142131979695
# Page Rank Centrality : Richard Layard 	 0.005076142131979695
# Page Rank Centrality : Danny Quah 	 0.005076142131979695
# Page Rank Centrality : Jean Tirole 	 0.005076142131979695
# Page Rank Centrality : Lawrence Katz 	 0.005076142131979695
# Page Rank Centrality : Peter Diamond 	 0.005076142131979695
# Page Rank Centrality : Philippe Aghion 	 0.005076142131979695
# Page Rank Centrality : Jeffrey Sachs 	 0.005076142131979695
# Page Rank Centrality : Andrew Abel 	 0.01015228426395939
# Page Rank Centrality : Pedro Portugal 	 0.005076142131979695
# Page Rank Centrality : Daniel Leigh 	 0.005076142131979695
# Page Rank Centrality : Gian Maria Milesi-Ferretti 	 0.005076142131979695
# Page Rank Centrality : Jonathan David Ostry 	 0.005076142131979695
# Page Rank Centrality : Jean-Paul L'Huillier 	 0.005076142131979695
# Page Rank Centrality : Guido Lorenzoni 	 0.005076142131979695
# Page Rank Centrality : Charles M. Kahn 	 0.005076142131979695
# Page Rank Centrality : Prakash Loungani 	 0.005076142131979695
# Page Rank Centrality : Joshua Gans 	 0.01015228426395939
# Page Rank Centrality : Alison Booth 	 0.005076142131979695
# Page Rank Centrality : Anthony Atkinson 	 0.005076142131979695
# Page Rank Centrality : Chris Ryan 	 0.005076142131979695
# Page Rank Centrality : Christine Neill 	 0.005076142131979695
# Page Rank Centrality : Amy King 	 0.005076142131979695
# Page Rank Centrality : Professor Caroline Hoxby 	 0.005076142131979695
# Page Rank Centrality : Paul J. Burke 	 0.005076142131979695
# Page Rank Centrality : Pierre van der Eng 	 0.005076142131979695
# Page Rank Centrality : Xiaodong Gong 	 0.005076142131979695
# Page Rank Centrality : David Burchell 	 0.005076142131979695
# Page Rank Centrality : Xin Meng 	 0.005076142131979695
# Page Rank Centrality : Michael Kortt 	 0.005076142131979695
# Page Rank Centrality : Timothy Smeeding 	 0.005076142131979695
# Page Rank Centrality : Paul Frijters 	 0.005076142131979695
# Page Rank Centrality : Naomi E. Feldman 	 0.005076142131979695
# Page Rank Centrality : Timothy J. Hatton 	 0.005076142131979695
# Page Rank Centrality : Chikako Yamauchi 	 0.005076142131979695
# Page Rank Centrality : David Weil 	 0.005076142131979695
# Page Rank Centrality : Laurence Ball 	 0.005076142131979695
# Page Rank Centrality : Matthew D. Shapiro 	 0.005076142131979695
# Page Rank Centrality : Mark P Taylor 	 0.005076142131979695
# Page Rank Centrality : John Y. Campbell 	 0.005076142131979695
# Page Rank Centrality : Jeffrey Alan Miron 	 0.005076142131979695
# Page Rank Centrality : Matthew Weinzierl 	 0.005076142131979695
# Page Rank Centrality : Stephen P. Zeldes 	 0.005076142131979695
# Page Rank Centrality : Richard Zeckhauser 	 0.01015228426395939
# Page Rank Centrality : Douglas Elmendorf 	 0.005076142131979695
# Page Rank Centrality : Phillip Swagel 	 0.005076142131979695
# Page Rank Centrality : Robert Barsky 	 0.005076142131979695
# Page Rank Centrality : Robert Hall 	 0.01015228426395939
# Page Rank Centrality : Michael Whinston 	 0.005076142131979695
# Page Rank Centrality : Stephen P King 	 0.005076142131979695
# Page Rank Centrality : Miles Kimball 	 0.005076142131979695
# Page Rank Centrality : Markus Brunnermeier 	 0.005076142131979695
# Page Rank Centrality : Marco Pagano 	 0.005076142131979695
# Page Rank Centrality : Dimitri Vayanos 	 0.005076142131979695
# Page Rank Centrality : Alisdair McKay 	 0.005076142131979695
# Page Rank Centrality : Luis Garicano 	 0.005076142131979695
# Page Rank Centrality : Tano Santos 	 0.005076142131979695
# Page Rank Centrality : Philip Lane 	 0.005076142131979695
# Page Rank Centrality : Hyunseung Oh 	 0.005076142131979695
# Page Rank Centrality : Vasco Cúrdia 	 0.005076142131979695
# Page Rank Centrality : Richard Thaler 	 0.005076142131979695
# Page Rank Centrality : David Schkade 	 0.005076142131979695
# Page Rank Centrality : Lucia Reisch 	 0.005076142131979695
# Page Rank Centrality : Daniel Kahneman 	 0.005076142131979695
# Page Rank Centrality : Eric Posner 	 0.005076142131979695
# Page Rank Centrality : Lawrence Lessig 	 0.005076142131979695
# Page Rank Centrality : Robert Hahn 	 0.005076142131979695
# Page Rank Centrality : shlomo benartzi 	 0.005076142131979695
# Page Rank Centrality : Timur Kuran 	 0.005076142131979695
# Page Rank Centrality : David Weisbach 	 0.005076142131979695
# Page Rank Centrality : Tali Sharot 	 0.005076142131979695
# Page Rank Centrality : Michael Greenstone 	 0.005076142131979695
# Page Rank Centrality : Edward Glaeser 	 0.005076142131979695
# Page Rank Centrality : Eric T. Swanson 	 0.005076142131979695
# Page Rank Centrality : Andrew Levin 	 0.005076142131979695
# Page Rank Centrality : Burcin Kisacikoglu 	 0.005076142131979695
# Page Rank Centrality : Michael Ehrmann 	 0.005076142131979695
# Page Rank Centrality : Harun Alp 	 0.005076142131979695
# Page Rank Centrality : Marcel Fratzscher 	 0.005076142131979695
# Page Rank Centrality : Barbara Rossi 	 0.005076142131979695
# Page Rank Centrality : Troy Davig 	 0.005076142131979695
# Page Rank Centrality : Hakan Kara 	 0.005076142131979695
# Page Rank Centrality : Seçil Yildirim Karaman 	 0.005076142131979695
# Page Rank Centrality : Ozge Akinci 	 0.005076142131979695
# Page Rank Centrality : Joseph E. Stiglitz 	 0.005076142131979695
# Page Rank Centrality : Mitchell Hoffman 	 0.005076142131979695
# Page Rank Centrality : Stephen V. Burks 	 0.005076142131979695
# Page Rank Centrality : Cosmina Dorobantu 	 0.005076142131979695
# Page Rank Centrality : Catherine Tucker 	 0.005076142131979695
# Page Rank Centrality : Kenneth C Wilbur 	 0.005076142131979695
# Page Rank Centrality : Mingyu (Max) Joo 	 0.005076142131979695
# Page Rank Centrality : Yi Zhu 	 0.005076142131979695
# Page Rank Centrality : Laura Katherine Gee 	 0.005076142131979695
# Page Rank Centrality : Amanda Agan 	 0.005076142131979695
# Page Rank Centrality : Kathryn Harrigan 	 0.005076142131979695
# Page Rank Centrality : Bertin Martens 	 0.005076142131979695
# Page Rank Centrality : Sandra C. Matz 	 0.005076142131979695
# Page Rank Centrality : Rembrand Koning 	 0.005076142131979695
# Page Rank Centrality : Megan T. Stevenson 	 0.005076142131979695
# Page Rank Centrality : Daniel Hsu 	 0.005076142131979695
# Page Rank Centrality : Augustin Chaintreau 	 0.005076142131979695
# Page Rank Centrality : Nakul Verma 	 0.005076142131979695
# Page Rank Centrality : John Horton 	 0.005076142131979695
# Page Rank Centrality : Sharad Goel 	 0.01015228426395939
# Page Rank Centrality : Andrew Gelman 	 0.005076142131979695
# Page Rank Centrality : Shawndra Hill 	 0.005076142131979695
# Page Rank Centrality : Daniel G Goldstein 	 0.005076142131979695
# Page Rank Centrality : Jake Hofman 	 0.01015228426395939
# Page Rank Centrality : Emre Kıcıman 	 0.005076142131979695
# Page Rank Centrality : Douglas Rivers 	 0.005076142131979695
# Page Rank Centrality : Miroslav Dudik 	 0.005076142131979695
# Page Rank Centrality : Fernando Diaz 	 0.005076142131979695
# Page Rank Centrality : Rajiv Sethi 	 0.005076142131979695
# Page Rank Centrality : Sébastien Lahaie 	 0.005076142131979695
# Page Rank Centrality : John R Anderson 	 0.005076142131979695
# Page Rank Centrality : Pavel Atanasov 	 0.005076142131979695
# Page Rank Centrality : Lyle Ungar 	 0.01015228426395939
# Page Rank Centrality : Samuel A Swift 	 0.005076142131979695
# Page Rank Centrality : Benoit Mulsant 	 0.005076142131979695
# Page Rank Centrality : Steve Lawrence 	 0.005076142131979695
# Page Rank Centrality : C Lee Giles 	 0.005076142131979695
# Page Rank Centrality : Gary William Flake 	 0.005076142131979695
# Page Rank Centrality : Yiling Chen 	 0.005076142131979695
# Page Rank Centrality : Daniel Reeves 	 0.005076142131979695
# Page Rank Centrality : Eric Horvitz 	 0.005076142131979695
# Page Rank Centrality : Andrew Schein 	 0.005076142131979695
# Page Rank Centrality : Lance Fortnow 	 0.005076142131979695
# Page Rank Centrality : Jennifer Wortman Vaughan 	 0.005076142131979695
# Page Rank Centrality : Finn Årup Nielsen 	 0.005076142131979695
# Page Rank Centrality : Michael Wellman 	 0.005076142131979695
# Page Rank Centrality : Duncan J Watts 	 0.005076142131979695
# Page Rank Centrality : Kushal Dave 	 0.005076142131979695
# Page Rank Centrality : Hemant K. Bhargava 	 0.005076142131979695
# Page Rank Centrality : Dmitry Pavlov 	 0.005076142131979695
# Page Rank Centrality : Frans M. Coetzee 	 0.005076142131979695
# Page Rank Centrality : David C. Parkes 	 0.005076142131979695
# Page Rank Centrality : Patrick Eichenberger 	 0.005076142131979695
# Page Rank Centrality : Stephen H. Shore 	 0.005076142131979695
# Page Rank Centrality : Christian Stoeckert 	 0.005076142131979695
# Page Rank Centrality : Zhi Wei 	 0.005076142131979695
# Page Rank Centrality : Blakeley McShane 	 0.005076142131979695
# Page Rank Centrality : Moises Goldszmidt 	 0.005076142131979695
# Page Rank Centrality : Nir Friedman 	 0.005076142131979695
# Page Rank Centrality : Peter Bühlmann 	 0.005076142131979695
# Page Rank Centrality : Dean Foster 	 0.005076142131979695
# Page Rank Centrality : Ioannis Kontoyiannis 	 0.005076142131979695
# Page Rank Centrality : Martin Farach-Colton 	 0.005076142131979695
# Page Rank Centrality : Serap Savari 	 0.005076142131979695
# Page Rank Centrality : Justin Bleich 	 0.005076142131979695
# Page Rank Centrality : Greg Maislin 	 0.005076142131979695
# Page Rank Centrality : Lu Sun 	 0.005076142131979695
# Page Rank Centrality : Eric Bradlow 	 0.005076142131979695
# Page Rank Centrality : Kenneth E. Shirley 	 0.005076142131979695
# Page Rank Centrality : Matthew G. Olson 	 0.005076142131979695

# %%
plot_(Gt)

# %%
mylist=[]
degree =  g.degree()
for k,v in degree :
    print('Degree of Each Node :',k,'\t',v)
    mylist.append(v)
# Out:
# Degree of Each Node : Justin Wolfers 	 32
# Degree of Each Node : Betsey Stevenson 	 5
# Degree of Each Node : Eric Zitzewitz 	 14
# Degree of Each Node : Erik Snowberg 	 24
# Degree of Each Node : olivier blanchard 	 24
# Degree of Each Node : Andrew Leigh 	 24
# Degree of Each Node : Daniel Sacks 	 4
# Degree of Each Node : N. Gregory Mankiw 	 25
# Degree of Each Node : Ricardo Reis 	 17
# Degree of Each Node : Cass Sunstein 	 18
# Degree of Each Node : Refet S. Gürkaynak 	 17
# Degree of Each Node : Devin Pope 	 4
# Degree of Each Node : Bo Cowgill 	 25
# Degree of Each Node : David Rothschild 	 18
# Degree of Each Node : Emile Servan-Schreiber 	 11
# Degree of Each Node : David M Pennock 	 26
# Degree of Each Node : Shane Jensen 	 10
# Degree of Each Node : Abraham Wyner 	 21
# Degree of Each Node : Sort by citations 	 18
# Degree of Each Node : Sort by year 	 18
# Degree of Each Node : Sort by title 	 18
# Degree of Each Node : Jonathan Reuter 	 1
# Degree of Each Node : Antti Petajisto 	 1
# Degree of Each Node : K. J. Martijn Cremers 	 1
# Degree of Each Node : Jonathan Zinman 	 1
# Degree of Each Node : Sylvain Chassang 	 1
# Degree of Each Node : Pietro Ortoleva 	 1
# Degree of Each Node : James Snyder 	 1
# Degree of Each Node : Marc Meredith 	 1
# Degree of Each Node : Gerard Padró i Miquel 	 1
# Degree of Each Node : Abhijit Banerjee 	 1
# Degree of Each Node : Leeat Yariv 	 1
# Degree of Each Node : Colin Camerer 	 1
# Degree of Each Node : Benjamin Gillen 	 1
# Degree of Each Node : Philippe Rigollet 	 1
# Degree of Each Node : Vianney Perchet 	 1
# Degree of Each Node : Mark Dean 	 1
# Degree of Each Node : Brendan Daley 	 1
# Degree of Each Node : Andrea Mattozzi 	 1
# Degree of Each Node : Ben Seymour 	 1
# Degree of Each Node : Neil Malhotra 	 2
# Degree of Each Node : Andrew Healy 	 1
# Degree of Each Node : Jordi Galí 	 1
# Degree of Each Node : Giovanni Dell'Ariccia 	 1
# Degree of Each Node : francesco giavazzi 	 1
# Degree of Each Node : Richard Layard 	 1
# Degree of Each Node : Danny Quah 	 1
# Degree of Each Node : Jean Tirole 	 1
# Degree of Each Node : Lawrence Katz 	 1
# Degree of Each Node : Peter Diamond 	 1
# Degree of Each Node : Philippe Aghion 	 1
# Degree of Each Node : Jeffrey Sachs 	 1
# Degree of Each Node : Andrew Abel 	 2
# Degree of Each Node : Pedro Portugal 	 1
# Degree of Each Node : Daniel Leigh 	 1
# Degree of Each Node : Gian Maria Milesi-Ferretti 	 1
# Degree of Each Node : Jonathan David Ostry 	 1
# Degree of Each Node : Jean-Paul L'Huillier 	 1
# Degree of Each Node : Guido Lorenzoni 	 1
# Degree of Each Node : Charles M. Kahn 	 1
# Degree of Each Node : Prakash Loungani 	 1
# Degree of Each Node : Joshua Gans 	 2
# Degree of Each Node : Alison Booth 	 1
# Degree of Each Node : Anthony Atkinson 	 1
# Degree of Each Node : Chris Ryan 	 1
# Degree of Each Node : Christine Neill 	 1
# Degree of Each Node : Amy King 	 1
# Degree of Each Node : Professor Caroline Hoxby 	 1
# Degree of Each Node : Paul J. Burke 	 1
# Degree of Each Node : Pierre van der Eng 	 1
# Degree of Each Node : Xiaodong Gong 	 1
# Degree of Each Node : David Burchell 	 1
# Degree of Each Node : Xin Meng 	 1
# Degree of Each Node : Michael Kortt 	 1
# Degree of Each Node : Timothy Smeeding 	 1
# Degree of Each Node : Paul Frijters 	 1
# Degree of Each Node : Naomi E. Feldman 	 1
# Degree of Each Node : Timothy J. Hatton 	 1
# Degree of Each Node : Chikako Yamauchi 	 1
# Degree of Each Node : David Weil 	 1
# Degree of Each Node : Laurence Ball 	 1
# Degree of Each Node : Matthew D. Shapiro 	 1
# Degree of Each Node : Mark P Taylor 	 1
# Degree of Each Node : John Y. Campbell 	 1
# Degree of Each Node : Jeffrey Alan Miron 	 1
# Degree of Each Node : Matthew Weinzierl 	 1
# Degree of Each Node : Stephen P. Zeldes 	 1
# Degree of Each Node : Richard Zeckhauser 	 2
# Degree of Each Node : Douglas Elmendorf 	 1
# Degree of Each Node : Phillip Swagel 	 1
# Degree of Each Node : Robert Barsky 	 1
# Degree of Each Node : Robert Hall 	 2
# Degree of Each Node : Michael Whinston 	 1
# Degree of Each Node : Stephen P King 	 1
# Degree of Each Node : Miles Kimball 	 1
# Degree of Each Node : Markus Brunnermeier 	 1
# Degree of Each Node : Marco Pagano 	 1
# Degree of Each Node : Dimitri Vayanos 	 1
# Degree of Each Node : Alisdair McKay 	 1
# Degree of Each Node : Luis Garicano 	 1
# Degree of Each Node : Tano Santos 	 1
# Degree of Each Node : Philip Lane 	 1
# Degree of Each Node : Hyunseung Oh 	 1
# Degree of Each Node : Vasco Cúrdia 	 1
# Degree of Each Node : Richard Thaler 	 1
# Degree of Each Node : David Schkade 	 1
# Degree of Each Node : Lucia Reisch 	 1
# Degree of Each Node : Daniel Kahneman 	 1
# Degree of Each Node : Eric Posner 	 1
# Degree of Each Node : Lawrence Lessig 	 1
# Degree of Each Node : Robert Hahn 	 1
# Degree of Each Node : shlomo benartzi 	 1
# Degree of Each Node : Timur Kuran 	 1
# Degree of Each Node : David Weisbach 	 1
# Degree of Each Node : Tali Sharot 	 1
# Degree of Each Node : Michael Greenstone 	 1
# Degree of Each Node : Edward Glaeser 	 1
# Degree of Each Node : Eric T. Swanson 	 1
# Degree of Each Node : Andrew Levin 	 1
# Degree of Each Node : Burcin Kisacikoglu 	 1
# Degree of Each Node : Michael Ehrmann 	 1
# Degree of Each Node : Harun Alp 	 1
# Degree of Each Node : Marcel Fratzscher 	 1
# Degree of Each Node : Barbara Rossi 	 1
# Degree of Each Node : Troy Davig 	 1
# Degree of Each Node : Hakan Kara 	 1
# Degree of Each Node : Seçil Yildirim Karaman 	 1
# Degree of Each Node : Ozge Akinci 	 1
# Degree of Each Node : Joseph E. Stiglitz 	 1
# Degree of Each Node : Mitchell Hoffman 	 1
# Degree of Each Node : Stephen V. Burks 	 1
# Degree of Each Node : Cosmina Dorobantu 	 1
# Degree of Each Node : Catherine Tucker 	 1
# Degree of Each Node : Kenneth C Wilbur 	 1
# Degree of Each Node : Mingyu (Max) Joo 	 1
# Degree of Each Node : Yi Zhu 	 1
# Degree of Each Node : Laura Katherine Gee 	 1
# Degree of Each Node : Amanda Agan 	 1
# Degree of Each Node : Kathryn Harrigan 	 1
# Degree of Each Node : Bertin Martens 	 1
# Degree of Each Node : Sandra C. Matz 	 1
# Degree of Each Node : Rembrand Koning 	 1
# Degree of Each Node : Megan T. Stevenson 	 1
# Degree of Each Node : Daniel Hsu 	 1
# Degree of Each Node : Augustin Chaintreau 	 1
# Degree of Each Node : Nakul Verma 	 1
# Degree of Each Node : John Horton 	 1
# Degree of Each Node : Sharad Goel 	 2
# Degree of Each Node : Andrew Gelman 	 1
# Degree of Each Node : Shawndra Hill 	 1
# Degree of Each Node : Daniel G Goldstein 	 1
# Degree of Each Node : Jake Hofman 	 2
# Degree of Each Node : Emre Kıcıman 	 1
# Degree of Each Node : Douglas Rivers 	 1
# Degree of Each Node : Miroslav Dudik 	 1
# Degree of Each Node : Fernando Diaz 	 1
# Degree of Each Node : Rajiv Sethi 	 1
# Degree of Each Node : Sébastien Lahaie 	 1
# Degree of Each Node : John R Anderson 	 1
# Degree of Each Node : Pavel Atanasov 	 1
# Degree of Each Node : Lyle Ungar 	 2
# Degree of Each Node : Samuel A Swift 	 1
# Degree of Each Node : Benoit Mulsant 	 1
# Degree of Each Node : Steve Lawrence 	 1
# Degree of Each Node : C Lee Giles 	 1
# Degree of Each Node : Gary William Flake 	 1
# Degree of Each Node : Yiling Chen 	 1
# Degree of Each Node : Daniel Reeves 	 1
# Degree of Each Node : Eric Horvitz 	 1
# Degree of Each Node : Andrew Schein 	 1
# Degree of Each Node : Lance Fortnow 	 1
# Degree of Each Node : Jennifer Wortman Vaughan 	 1
# Degree of Each Node : Finn Årup Nielsen 	 1
# Degree of Each Node : Michael Wellman 	 1
# Degree of Each Node : Duncan J Watts 	 1
# Degree of Each Node : Kushal Dave 	 1
# Degree of Each Node : Hemant K. Bhargava 	 1
# Degree of Each Node : Dmitry Pavlov 	 1
# Degree of Each Node : Frans M. Coetzee 	 1
# Degree of Each Node : David C. Parkes 	 1
# Degree of Each Node : Patrick Eichenberger 	 1
# Degree of Each Node : Stephen H. Shore 	 1
# Degree of Each Node : Christian Stoeckert 	 1
# Degree of Each Node : Zhi Wei 	 1
# Degree of Each Node : Blakeley McShane 	 1
# Degree of Each Node : Moises Goldszmidt 	 1
# Degree of Each Node : Nir Friedman 	 1
# Degree of Each Node : Peter Bühlmann 	 1
# Degree of Each Node : Dean Foster 	 1
# Degree of Each Node : Ioannis Kontoyiannis 	 1
# Degree of Each Node : Martin Farach-Colton 	 1
# Degree of Each Node : Serap Savari 	 1
# Degree of Each Node : Justin Bleich 	 1
# Degree of Each Node : Greg Maislin 	 1
# Degree of Each Node : Lu Sun 	 1
# Degree of Each Node : Eric Bradlow 	 1
# Degree of Each Node : Kenneth E. Shirley 	 1
# Degree of Each Node : Matthew G. Olson 	 1

# %%
plt.figure(figsize = (8, 5))
plt.hist(mylist)
plt.title("Degree Distribution", fontsize = 15)
plt.show()

# %%
centality_value = []
centrality =  nx.degree_centrality(g)
for each in centrality.items():
    print('Degree Centrality: ', each[0], '\t', each[1])
    centality_value.append(each[1])
# Out:
# Degree Centrality:  Justin Wolfers 	 0.16243654822335024
# Degree Centrality:  Betsey Stevenson 	 0.025380710659898477
# Degree Centrality:  Eric Zitzewitz 	 0.07106598984771573
# Degree Centrality:  Erik Snowberg 	 0.12182741116751268
# Degree Centrality:  olivier blanchard 	 0.12182741116751268
# Degree Centrality:  Andrew Leigh 	 0.12182741116751268
# Degree Centrality:  Daniel Sacks 	 0.02030456852791878
# Degree Centrality:  N. Gregory Mankiw 	 0.12690355329949238
# Degree Centrality:  Ricardo Reis 	 0.08629441624365482
# Degree Centrality:  Cass Sunstein 	 0.09137055837563451
# Degree Centrality:  Refet S. Gürkaynak 	 0.08629441624365482
# Degree Centrality:  Devin Pope 	 0.02030456852791878
# Degree Centrality:  Bo Cowgill 	 0.12690355329949238
# Degree Centrality:  David Rothschild 	 0.09137055837563451
# Degree Centrality:  Emile Servan-Schreiber 	 0.055837563451776644
# Degree Centrality:  David M Pennock 	 0.13197969543147206
# Degree Centrality:  Shane Jensen 	 0.050761421319796954
# Degree Centrality:  Abraham Wyner 	 0.10659898477157359
# Degree Centrality:  Sort by citations 	 0.09137055837563451
# Degree Centrality:  Sort by year 	 0.09137055837563451
# Degree Centrality:  Sort by title 	 0.09137055837563451
# Degree Centrality:  Jonathan Reuter 	 0.005076142131979695
# Degree Centrality:  Antti Petajisto 	 0.005076142131979695
# Degree Centrality:  K. J. Martijn Cremers 	 0.005076142131979695
# Degree Centrality:  Jonathan Zinman 	 0.005076142131979695
# Degree Centrality:  Sylvain Chassang 	 0.005076142131979695
# Degree Centrality:  Pietro Ortoleva 	 0.005076142131979695
# Degree Centrality:  James Snyder 	 0.005076142131979695
# Degree Centrality:  Marc Meredith 	 0.005076142131979695
# Degree Centrality:  Gerard Padró i Miquel 	 0.005076142131979695
# Degree Centrality:  Abhijit Banerjee 	 0.005076142131979695
# Degree Centrality:  Leeat Yariv 	 0.005076142131979695
# Degree Centrality:  Colin Camerer 	 0.005076142131979695
# Degree Centrality:  Benjamin Gillen 	 0.005076142131979695
# Degree Centrality:  Philippe Rigollet 	 0.005076142131979695
# Degree Centrality:  Vianney Perchet 	 0.005076142131979695
# Degree Centrality:  Mark Dean 	 0.005076142131979695
# Degree Centrality:  Brendan Daley 	 0.005076142131979695
# Degree Centrality:  Andrea Mattozzi 	 0.005076142131979695
# Degree Centrality:  Ben Seymour 	 0.005076142131979695
# Degree Centrality:  Neil Malhotra 	 0.01015228426395939
# Degree Centrality:  Andrew Healy 	 0.005076142131979695
# Degree Centrality:  Jordi Galí 	 0.005076142131979695
# Degree Centrality:  Giovanni Dell'Ariccia 	 0.005076142131979695
# Degree Centrality:  francesco giavazzi 	 0.005076142131979695
# Degree Centrality:  Richard Layard 	 0.005076142131979695
# Degree Centrality:  Danny Quah 	 0.005076142131979695
# Degree Centrality:  Jean Tirole 	 0.005076142131979695
# Degree Centrality:  Lawrence Katz 	 0.005076142131979695
# Degree Centrality:  Peter Diamond 	 0.005076142131979695
# Degree Centrality:  Philippe Aghion 	 0.005076142131979695
# Degree Centrality:  Jeffrey Sachs 	 0.005076142131979695
# Degree Centrality:  Andrew Abel 	 0.01015228426395939
# Degree Centrality:  Pedro Portugal 	 0.005076142131979695
# Degree Centrality:  Daniel Leigh 	 0.005076142131979695
# Degree Centrality:  Gian Maria Milesi-Ferretti 	 0.005076142131979695
# Degree Centrality:  Jonathan David Ostry 	 0.005076142131979695
# Degree Centrality:  Jean-Paul L'Huillier 	 0.005076142131979695
# Degree Centrality:  Guido Lorenzoni 	 0.005076142131979695
# Degree Centrality:  Charles M. Kahn 	 0.005076142131979695
# Degree Centrality:  Prakash Loungani 	 0.005076142131979695
# Degree Centrality:  Joshua Gans 	 0.01015228426395939
# Degree Centrality:  Alison Booth 	 0.005076142131979695
# Degree Centrality:  Anthony Atkinson 	 0.005076142131979695
# Degree Centrality:  Chris Ryan 	 0.005076142131979695
# Degree Centrality:  Christine Neill 	 0.005076142131979695
# Degree Centrality:  Amy King 	 0.005076142131979695
# Degree Centrality:  Professor Caroline Hoxby 	 0.005076142131979695
# Degree Centrality:  Paul J. Burke 	 0.005076142131979695
# Degree Centrality:  Pierre van der Eng 	 0.005076142131979695
# Degree Centrality:  Xiaodong Gong 	 0.005076142131979695
# Degree Centrality:  David Burchell 	 0.005076142131979695
# Degree Centrality:  Xin Meng 	 0.005076142131979695
# Degree Centrality:  Michael Kortt 	 0.005076142131979695
# Degree Centrality:  Timothy Smeeding 	 0.005076142131979695
# Degree Centrality:  Paul Frijters 	 0.005076142131979695
# Degree Centrality:  Naomi E. Feldman 	 0.005076142131979695
# Degree Centrality:  Timothy J. Hatton 	 0.005076142131979695
# Degree Centrality:  Chikako Yamauchi 	 0.005076142131979695
# Degree Centrality:  David Weil 	 0.005076142131979695
# Degree Centrality:  Laurence Ball 	 0.005076142131979695
# Degree Centrality:  Matthew D. Shapiro 	 0.005076142131979695
# Degree Centrality:  Mark P Taylor 	 0.005076142131979695
# Degree Centrality:  John Y. Campbell 	 0.005076142131979695
# Degree Centrality:  Jeffrey Alan Miron 	 0.005076142131979695
# Degree Centrality:  Matthew Weinzierl 	 0.005076142131979695
# Degree Centrality:  Stephen P. Zeldes 	 0.005076142131979695
# Degree Centrality:  Richard Zeckhauser 	 0.01015228426395939
# Degree Centrality:  Douglas Elmendorf 	 0.005076142131979695
# Degree Centrality:  Phillip Swagel 	 0.005076142131979695
# Degree Centrality:  Robert Barsky 	 0.005076142131979695
# Degree Centrality:  Robert Hall 	 0.01015228426395939
# Degree Centrality:  Michael Whinston 	 0.005076142131979695
# Degree Centrality:  Stephen P King 	 0.005076142131979695
# Degree Centrality:  Miles Kimball 	 0.005076142131979695
# Degree Centrality:  Markus Brunnermeier 	 0.005076142131979695
# Degree Centrality:  Marco Pagano 	 0.005076142131979695
# Degree Centrality:  Dimitri Vayanos 	 0.005076142131979695
# Degree Centrality:  Alisdair McKay 	 0.005076142131979695
# Degree Centrality:  Luis Garicano 	 0.005076142131979695
# Degree Centrality:  Tano Santos 	 0.005076142131979695
# Degree Centrality:  Philip Lane 	 0.005076142131979695
# Degree Centrality:  Hyunseung Oh 	 0.005076142131979695
# Degree Centrality:  Vasco Cúrdia 	 0.005076142131979695
# Degree Centrality:  Richard Thaler 	 0.005076142131979695
# Degree Centrality:  David Schkade 	 0.005076142131979695
# Degree Centrality:  Lucia Reisch 	 0.005076142131979695
# Degree Centrality:  Daniel Kahneman 	 0.005076142131979695
# Degree Centrality:  Eric Posner 	 0.005076142131979695
# Degree Centrality:  Lawrence Lessig 	 0.005076142131979695
# Degree Centrality:  Robert Hahn 	 0.005076142131979695
# Degree Centrality:  shlomo benartzi 	 0.005076142131979695
# Degree Centrality:  Timur Kuran 	 0.005076142131979695
# Degree Centrality:  David Weisbach 	 0.005076142131979695
# Degree Centrality:  Tali Sharot 	 0.005076142131979695
# Degree Centrality:  Michael Greenstone 	 0.005076142131979695
# Degree Centrality:  Edward Glaeser 	 0.005076142131979695
# Degree Centrality:  Eric T. Swanson 	 0.005076142131979695
# Degree Centrality:  Andrew Levin 	 0.005076142131979695
# Degree Centrality:  Burcin Kisacikoglu 	 0.005076142131979695
# Degree Centrality:  Michael Ehrmann 	 0.005076142131979695
# Degree Centrality:  Harun Alp 	 0.005076142131979695
# Degree Centrality:  Marcel Fratzscher 	 0.005076142131979695
# Degree Centrality:  Barbara Rossi 	 0.005076142131979695
# Degree Centrality:  Troy Davig 	 0.005076142131979695
# Degree Centrality:  Hakan Kara 	 0.005076142131979695
# Degree Centrality:  Seçil Yildirim Karaman 	 0.005076142131979695
# Degree Centrality:  Ozge Akinci 	 0.005076142131979695
# Degree Centrality:  Joseph E. Stiglitz 	 0.005076142131979695
# Degree Centrality:  Mitchell Hoffman 	 0.005076142131979695
# Degree Centrality:  Stephen V. Burks 	 0.005076142131979695
# Degree Centrality:  Cosmina Dorobantu 	 0.005076142131979695
# Degree Centrality:  Catherine Tucker 	 0.005076142131979695
# Degree Centrality:  Kenneth C Wilbur 	 0.005076142131979695
# Degree Centrality:  Mingyu (Max) Joo 	 0.005076142131979695
# Degree Centrality:  Yi Zhu 	 0.005076142131979695
# Degree Centrality:  Laura Katherine Gee 	 0.005076142131979695
# Degree Centrality:  Amanda Agan 	 0.005076142131979695
# Degree Centrality:  Kathryn Harrigan 	 0.005076142131979695
# Degree Centrality:  Bertin Martens 	 0.005076142131979695
# Degree Centrality:  Sandra C. Matz 	 0.005076142131979695
# Degree Centrality:  Rembrand Koning 	 0.005076142131979695
# Degree Centrality:  Megan T. Stevenson 	 0.005076142131979695
# Degree Centrality:  Daniel Hsu 	 0.005076142131979695
# Degree Centrality:  Augustin Chaintreau 	 0.005076142131979695
# Degree Centrality:  Nakul Verma 	 0.005076142131979695
# Degree Centrality:  John Horton 	 0.005076142131979695
# Degree Centrality:  Sharad Goel 	 0.01015228426395939
# Degree Centrality:  Andrew Gelman 	 0.005076142131979695
# Degree Centrality:  Shawndra Hill 	 0.005076142131979695
# Degree Centrality:  Daniel G Goldstein 	 0.005076142131979695
# Degree Centrality:  Jake Hofman 	 0.01015228426395939
# Degree Centrality:  Emre Kıcıman 	 0.005076142131979695
# Degree Centrality:  Douglas Rivers 	 0.005076142131979695
# Degree Centrality:  Miroslav Dudik 	 0.005076142131979695
# Degree Centrality:  Fernando Diaz 	 0.005076142131979695
# Degree Centrality:  Rajiv Sethi 	 0.005076142131979695
# Degree Centrality:  Sébastien Lahaie 	 0.005076142131979695
# Degree Centrality:  John R Anderson 	 0.005076142131979695
# Degree Centrality:  Pavel Atanasov 	 0.005076142131979695
# Degree Centrality:  Lyle Ungar 	 0.01015228426395939
# Degree Centrality:  Samuel A Swift 	 0.005076142131979695
# Degree Centrality:  Benoit Mulsant 	 0.005076142131979695
# Degree Centrality:  Steve Lawrence 	 0.005076142131979695
# Degree Centrality:  C Lee Giles 	 0.005076142131979695
# Degree Centrality:  Gary William Flake 	 0.005076142131979695
# Degree Centrality:  Yiling Chen 	 0.005076142131979695
# Degree Centrality:  Daniel Reeves 	 0.005076142131979695
# Degree Centrality:  Eric Horvitz 	 0.005076142131979695
# Degree Centrality:  Andrew Schein 	 0.005076142131979695
# Degree Centrality:  Lance Fortnow 	 0.005076142131979695
# Degree Centrality:  Jennifer Wortman Vaughan 	 0.005076142131979695
# Degree Centrality:  Finn Årup Nielsen 	 0.005076142131979695
# Degree Centrality:  Michael Wellman 	 0.005076142131979695
# Degree Centrality:  Duncan J Watts 	 0.005076142131979695
# Degree Centrality:  Kushal Dave 	 0.005076142131979695
# Degree Centrality:  Hemant K. Bhargava 	 0.005076142131979695
# Degree Centrality:  Dmitry Pavlov 	 0.005076142131979695
# Degree Centrality:  Frans M. Coetzee 	 0.005076142131979695
# Degree Centrality:  David C. Parkes 	 0.005076142131979695
# Degree Centrality:  Patrick Eichenberger 	 0.005076142131979695
# Degree Centrality:  Stephen H. Shore 	 0.005076142131979695
# Degree Centrality:  Christian Stoeckert 	 0.005076142131979695
# Degree Centrality:  Zhi Wei 	 0.005076142131979695
# Degree Centrality:  Blakeley McShane 	 0.005076142131979695
# Degree Centrality:  Moises Goldszmidt 	 0.005076142131979695
# Degree Centrality:  Nir Friedman 	 0.005076142131979695
# Degree Centrality:  Peter Bühlmann 	 0.005076142131979695
# Degree Centrality:  Dean Foster 	 0.005076142131979695
# Degree Centrality:  Ioannis Kontoyiannis 	 0.005076142131979695
# Degree Centrality:  Martin Farach-Colton 	 0.005076142131979695
# Degree Centrality:  Serap Savari 	 0.005076142131979695
# Degree Centrality:  Justin Bleich 	 0.005076142131979695
# Degree Centrality:  Greg Maislin 	 0.005076142131979695
# Degree Centrality:  Lu Sun 	 0.005076142131979695
# Degree Centrality:  Eric Bradlow 	 0.005076142131979695
# Degree Centrality:  Kenneth E. Shirley 	 0.005076142131979695
# Degree Centrality:  Matthew G. Olson 	 0.005076142131979695

# %%
avg_centrality =  sum(centrality.values())/len(centrality)
print('Average Degree Centrality: ', avg_centrality)
# Out:
# Average Degree Centrality:  0.01430549146285195

# %%
#create dataframe
import pandas as pd
y=list(centrality.values())
x=list(centrality.keys())
data = {'keys':x,'values':y}
df1 = pd.DataFrame.from_dict(data)

import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
fig = px.histogram(df1,
        x = "values",
        title = 'Degree Centrality Distribution', 
        #xaxis_title_text='Value',
        labels={'Number of coauthors':'centrality distribution'},
        color_discrete_sequence=['indianred'],
        opacity=0.9
        #log_y=True,
        )
fig.update_layout(
    xaxis_title_text='Degree', # xaxis label
    yaxis_title_text='Number of coauthors', # yaxis label
    #bargap=0.2, # gap between bars of adjacent location coordinates
    #bargroupgap=0.1 # gap between bars of the same location coordinates
)
#layout = go.Layout(title=go.layout.Title(text='Degree Centrality Distribution'),xaxis=go.layout.XAxis(title=go.layout.xaxis.Title(text='Number of Coauthors')),yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='Degree Centrality')))
#fig = go.Figure(data=data,layout=layout)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-c4cfe30698db> in <module>
#       6 df1 = pd.DataFrame.from_dict(data)
#       7
# ----> 8 import plotly
#       9 plotly.offline.init_notebook_mode(connected=True)
#      10 import plotly.graph_objs as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
close = nx.closeness_centrality(g)    
for each in close.items():
    print('Closeness Centrality: ', each[0], '\t', each[1])

# %%
y=list(close.values())
x=list(close.keys())
data = {'keys':x,'values':y}
df1 = pd.DataFrame.from_dict(data)

import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
fig = px.histogram(df1,
        x = "values",
        title = 'Clossness Centrality Distribution', 
        #xaxis_title_text='Value',
        labels={'Number of coauthors':'centrality distribution'},
        #color_discrete_sequence=['indianred'],
        opacity=0.9
        #log_y=True,
        )
fig.update_layout(
    xaxis_title_text='closeness centrality', # xaxis label
    yaxis_title_text='Number of coauthors', # yaxis label
    #bargap=0.2, # gap between bars of adjacent location coordinates
    #bargroupgap=0.1 # gap between bars of the same location coordinates
)
#layout = go.Layout(title=go.layout.Title(text='Degree Centrality Distribution'),xaxis=go.layout.XAxis(title=go.layout.xaxis.Title(text='Number of Coauthors')),yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='Degree Centrality')))
#fig = go.Figure(data=data,layout=layout)
fig.show()

# %%
btwn = nx.betweenness_centrality(g, weight='weight')
for each in btwn.items():
    print('Betweeness Centrality: ', each[0], '\t', each[1])

# %%
avg_betweenness =  sum(btwn.values())/len(btwn)
print('Avergage Betweenness: ', avg_betweenness)

# %%
y=list(btwn.values())
x=list(btwn.keys())
data = {'keys':x,'values':y}
df1 = pd.DataFrame.from_dict(data)

import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
fig = px.histogram(df1,
        x = "values",
        title = 'Betweeness Centrality Distribution', 
        #xaxis_title_text='Value',
        labels={'Number of coauthors':'centrality distribution'},
        color_discrete_sequence=['green'],
        opacity=0.9
        #log_y=True,
        )
fig.update_layout(
    xaxis_title_text='closeness centrality', # xaxis label
    yaxis_title_text='Number of coauthors', # yaxis label
    #bargap=0.2, # gap between bars of adjacent location coordinates
    #bargroupgap=0.1 # gap between bars of the same location coordinates
)
#layout = go.Layout(title=go.layout.Title(text='Degree Centrality Distribution'),xaxis=go.layout.XAxis(title=go.layout.xaxis.Title(text='Number of Coauthors')),yaxis=go.layout.YAxis(title=go.layout.yaxis.Title(text='Degree Centrality')))
#fig = go.Figure(data=data,layout=layout)
fig.show()
